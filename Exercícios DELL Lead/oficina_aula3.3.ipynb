# %% [markdown]
# ## Questão 01

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style='darkgrid')

# %%
shampoo_uri = 'https://d11s0xq1vqg039.cloudfront.net/videos_conteudo/visual/micro07/oficina/arquivos/dadosoficina07.txt'
shampoo = pd.read_csv(shampoo_uri)
shampoo.head()
# Out:
#   Month  Sales
# 0  1-01  266.0
# 1  1-02  145.9
# 2  1-03  183.1
# 3  1-04  119.3
# 4  1-05  180.3

# %% [markdown]
# ## Questão 02

# %%
plt.figure(figsize=(25,10))
plt.title('Quantidade de vendas ao longo dos meses\n')
sns.lineplot(x='Month', y='Sales', ci=None, data=shampoo)
plt.xlabel('Data (meses)')
plt.ylabel('Quantidade de vendas\n')
plt.show()
