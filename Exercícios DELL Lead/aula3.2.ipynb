# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style='darkgrid')

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## Exemplo 01

# %%
plt.figure(figsize=(10,5))
plt.title('Relação entre valor da conta e valor da gorjeta\n')
sns.scatterplot(x='total_bill', y= 'tip', data=tips)
plt.xlabel('Valor da conta (R$)')
plt.ylabel('Valor da gorjeta (R$)\n')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Relação entre valor da conta e valor da gorjeta\n')
sns.regplot(x='total_bill', y= 'tip', data=tips)
plt.xlabel('Valor da conta (R$)')
plt.ylabel('Valor da gorjeta (R$)\n')
plt.show()

# %% [markdown]
# ## Exemplo 02

# %%
plt.figure(figsize=(10,5))
plt.title('Relação entre valor da conta e valor da gorjeta\n')
sns.scatterplot(x='total_bill', y= 'tip', hue='sex', data=tips)
plt.xlabel('Valor da conta (R$)')
plt.ylabel('Valor da gorjeta (R$)\n')
plt.show()

# %%
#FacetGrid (não permite o matplotlib)
sns.relplot(x='total_bill', y= 'tip', col='day', data=tips)
plt.show()

# %%
#FacetGrid (não permite o matplotlib)
sns.lmplot(x='total_bill', y= 'tip', hue='sex', data=tips)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Relação entre valor da conta e valor da gorjeta\n')
sns.scatterplot(x='total_bill', y= 'tip', hue='size', data=tips)
plt.xlabel('Valor da conta (R$)')
plt.ylabel('Valor da gorjeta (R$)\n')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Relação entre valor da conta e valor da gorjeta\n')
sns.scatterplot(x='total_bill', y= 'tip', size='size', data=tips)
plt.xlabel('Valor da conta (R$)')
plt.ylabel('Valor da gorjeta (R$)\n')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Relação entre valor da conta e valor da gorjeta\n')
sns.scatterplot(x='total_bill', y= 'tip', size='size', hue='sex', style='smoker', data=tips)
plt.xlabel('Valor da conta (R$)')
plt.ylabel('Valor da gorjeta (R$)\n')
plt.show()
