# %% [markdown]
# ## Questão 01

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_uri = 'https://d11s0xq1vqg039.cloudfront.net/videos_conteudo/visual/micro05/oficina/arquivos/dadosoficina05.txt'
df = pd.read_csv(df_uri)

# %%
df.head()
# Out:
#              city  area  rooms  bathroom  parking spaces floor     animal  \
# 0       São Paulo    70      2         1               1     7      acept
# 1    Porto Alegre    80      1         1               1     6      acept
# 2    Porto Alegre    51      2         1               0     2      acept
# 3       São Paulo    25      1         1               0     1  not acept
# 4  Rio de Janeiro    72      2         1               0     7      acept
#
#        furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# 0      furnished      2065              3300                211
# 1  not furnished      1000              2800                  0
# 2  not furnished       270              1112                 22
# 3  not furnished         0               800                 25
# 4  not furnished       740              1900                 85
#
#    fire insurance (R$)  total (R$)
# 0                   42        5618
# 1                   41        3841
# ...

# %% [markdown]
# ## Questão 02

# %%
plt.figure(figsize=(15,5))
plt.title('Distribuição de áreas dos imóveis\n')
sns.distplot(df['rent amount (R$)'])
plt.xlabel('Valor do aluguel (R$)')
plt.ylabel('Densidade\n')
plt.show()

# %% [markdown]
# #### A faixa de valores mais comum é entre 1500 e 2500 reais

# %% [markdown]
# ## Questão 03

# %%
plt.figure(figsize=(15,5))
plt.title('Distribuição de áreas dos imóveis\n')
sns.distplot(df['fire insurance (R$)'])
plt.xlabel('Seguro contra incêndio (R$)')
plt.ylabel('Densidade\n')
plt.show()

# %% [markdown]
# #### Não existem valores incomuns
